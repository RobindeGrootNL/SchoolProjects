# %%
import matplotlib.pyplot as plt
import math
import numpy as np
import pylab as pyl
from scipy import signal
from scipy.io import wavfile
import seaborn as sns
sns.set()

# %matplotlib inline

# %% [markdown]
# ## Audio noise
#
# The audio noise is worked on first. Let's import the data!

# %%
def import_audio(filepath):
    try:
        fs, data = wavfile.read(filepath)
    except:
        print("ERROR: Please use a .wav file")
    
    # From stereo to mono
    try:
        if data.shape[1] > 1:
            monodata = (data[:,0] / 2 + data[:,1] / 2)
            print("File is transformed to a mono file.")
    except:
        monodata = data
        print("File is already a mono file.")
    return fs, data

# %%
filenames = ['./Data/noise1.wav', './Data/noise2.wav', './Data/noise3.wav']

fs_1, noise_1 = import_audio(filenames[0])
fs_2, noise_2 = import_audio(filenames[1])
fs_3, noise_3 = import_audio(filenames[2])
# Out:
# File is already a mono file.
# File is already a mono file.
# File is already a mono file.

# %% [markdown]
# ### Noise 1
#
# Firstly, the processes are performed on noise 1.

# %% [markdown]
# #### Periodogram analysis
#
# The following plot portrays the periodogram analysis of noise 1.

# %%
f_p1, Pxx_den_p1 = signal.periodogram(noise_1, fs_1)
plt.semilogy(f_p1, Pxx_den_p1)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
np.mean(Pxx_den_p1)
# Out:
# 6173.3994

# %%
f_p1, Pxx_spec_p1 = signal.periodogram(noise_1, fs_1, 'flattop', scaling='spectrum')
plt.figure()
plt.semilogy(f_p1, np.sqrt(Pxx_spec_p1))
plt.xlabel('frequency [Hz]')
plt.ylabel('Linear spectrum [V RMS]')
plt.show()

# %%
np.sqrt(Pxx_spec_p1.max())
# Out:
# 168.11313

# %% [markdown]
# #### Welsh method
#
# The following plots portray the Welsh method analysis of the audio noise.

# %%
f_w1, Pxx_spec_w1 = signal.welch(noise_1, fs_1)
plt.semilogy(f_w1, Pxx_spec_w1)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
np.mean(Pxx_spec_w1)
# Out:
# 6100.3657

# %%
f_w1, Pxx_spec_w1 = signal.welch(noise_1, fs_1, 'flattop', scaling='spectrum')
plt.semilogy(f_w1, Pxx_spec_w1)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
np.sqrt(Pxx_spec_w1.max())
# Out:
# 1252.4299

# %% [markdown]
# The noise spectra show a clear flat characteristic. The only colour noise that has such a flat characteristic is white noise, and therefore the noise present in this file is to be considered as white noise.

# %% [markdown]
# ### Noise 2
#
# Secondly, the processes are performed on noise 2.

# %% [markdown]
# #### Periodogram analysis
#
# The following plot portrays the periodogram analysis of noise 1.

# %%
f_p2, Pxx_den_p2 = signal.periodogram(noise_2, fs_2)
plt.semilogy(f_p2, Pxx_den_p2)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
np.mean(Pxx_den_p2)
# Out:
# 7064.824

# %%
f_p2, Pxx_spec_p2 = signal.periodogram(noise_2, fs_2, 'flattop', scaling='spectrum')
plt.figure()
plt.semilogy(f_p2, np.sqrt(Pxx_spec_p2))
plt.xlabel('frequency [Hz]')
plt.ylabel('Linear spectrum [V RMS]')
plt.show()

# %%
np.sqrt(Pxx_spec_p2.max())
# Out:
# 5844.1504

# %% [markdown]
# #### Welsh method
#
# The following plots portray the Welsh method analysis of the audio noise.

# %%
f_w2, Pxx_spec_w2 = signal.welch(noise_2, fs_2)
plt.semilogy(f_w2, Pxx_spec_w2)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
np.mean(Pxx_spec_w2)
# Out:
# 3256.765

# %%
f_w2, Pxx_spec_w2 = signal.welch(noise_2, fs_2, 'flattop', scaling='spectrum')
plt.semilogy(f_w2, Pxx_spec_w2)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
np.sqrt(Pxx_spec_w2.max())
# Out:
# 3020.0403

# %% [markdown]
# The plots show a decreasing line, even in the logarithmic spectrum. The decreasing nature means that it can be either pink or brown noise, though in this case it must be brown noise since it doesn't portray a linear decreasing nature in the frequency spectrum.

# %% [markdown]
# ### Noise 3
#
# Thirdly, the processes are performed on noise 3.

# %% [markdown]
# #### Periodogram analysis
#
# The following plot portrays the periodogram analysis of noise 1.

# %%
f_p3, Pxx_den_p3 = signal.periodogram(noise_3, fs_3)
plt.semilogy(f_p3, Pxx_den_p3)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
np.mean(Pxx_den_p3)
# Out:
# 6107.362

# %%
f_p3, Pxx_spec_p3 = signal.periodogram(noise_3, fs_3, 'flattop', scaling='spectrum')
plt.figure()
plt.plot(f_p3, np.sqrt(Pxx_spec_p3))
plt.xlabel('frequency [Hz]')
plt.ylabel('Linear spectrum [V RMS]')
plt.ylim(-100, 300)
plt.show()

# %%
np.sqrt(Pxx_spec_p3.max())
# Out:
# 3860.6392

# %% [markdown]
# #### Welsh method
#
# The following plots portray the Welsh method analysis of the audio noise.

# %%
f_w3, Pxx_spec_w3 = signal.welch(noise_3, fs_3)
plt.semilogy(f_w3, Pxx_spec_w3)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
np.mean(Pxx_spec_w3)
# Out:
# 4431.968

# %%
f_w3, Pxx_spec_w3 = signal.welch(noise_3, fs_3, 'flattop', scaling='spectrum')
plt.semilogy(f_w3, Pxx_spec_w3)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %%
np.sqrt(Pxx_spec_w3.max())
# Out:
# 2111.3162

# %%
f_w3, Pxx_spec_w3 = signal.welch(noise_3, fs_3, 'flattop', scaling='spectrum')
plt.semilogy(f_w3, Pxx_spec_w3)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

# %% [markdown]
# The noise in noise file 3 shows an almost linear decrease in the frequency spectrum between 1000 and 7500 Hz. Therefore, the noise present in this file is most likely pink noise.
